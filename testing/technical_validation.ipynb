# %% [markdown]
# # Technical Validation

# %%
from testing import *

# %%
run_fea_validation()
# Out:
# Running FEA Tests
# ...
#
# Executing Element Mathematics Test...
# Element Stiffness Analysis:
# Lowest eigenvalues: [0.04840486 0.04840487 0.04840488]
# Mode separation ratio: 7.65e+04
# Matrix conditioning: 3.83e+09
# Element Mathematics: PASS
#
# Executing Physical Behavior Test...
# Force 1/1 processed successfully
#
# All forces processed - solution complete
# Force 1/1 processed successfully
#
# All forces processed - solution complete
# Physical Behavior: PASS
#
# Executing Mesh Connectivity Test...
# Mesh Connectivity: PASS
#
# Executing Bending-Shear Coupling Test...
# Bending-Shear Coupling: PASS
#
# Executing Boundary Conditions Test...
# Force 1/1 processed successfully
#
# All forces processed - solution complete
# Force 1/1 processed successfully
#
# All forces processed - solution complete
# Boundary Conditions: PASS
#
# Test Summary
# ...
# Tests Passed: 5/5
# ✓ Element Mathematics
# ✓ Physical Behavior
# ✓ Mesh Connectivity
# ✓ Bending-Shear Coupling
# ✓ Boundary Conditions
# ...
